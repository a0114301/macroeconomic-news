# %%
import pandas as pd
import numpy as np
import statsmodels.tsa.stattools
from scipy import stats
from statsmodels.stats.diagnostic import acorr_ljungbox
df = pd.read_excel (r'C:\Users\SS\Downloads\data.xlsx',sheet_name='NFP ')
df=pd.DataFrame(df)
print(df)
# Out:
#     Unnamed: 0       sur    five  thirty   sixty   Efive  Ethirty  Esixty  \
# 0   2020-10-31  0.310160  0.0693 -0.0921  0.0325 -0.3204  -0.5535 -0.1038
# 1   2020-09-30 -0.770428  0.0181  0.1227  0.1579 -0.0192   0.3753  0.6535
# 2   2020-08-31  0.047619  0.0194  0.2942  0.3503  0.6162  -0.5316 -1.7495
# 3   2020-07-31  0.345122 -0.0129 -0.0751  0.3489  0.0380   0.1470  0.0862
# 4   2020-06-30  1.051574 -0.0526  0.1062  0.1248  0.5414   0.6257  0.0410
# ..         ...       ...     ...     ...     ...     ...      ...     ...
# 150 2008-04-30  2.115385  0.5315  0.4741  0.5274  0.7969   0.8487  0.5053
# 151 2008-03-31 -0.937500 -0.3843 -0.0014 -0.1276 -0.1131  -0.0277 -0.2723
# 152 2008-02-29 -2.515152 -0.0110  0.0661  0.2575 -0.6362   0.4610  0.2943
# 153 2008-01-31 -2.900000 -0.1837 -0.0812  0.1265  0.2408   0.6891  0.5012
# 154 2007-12-31 -3.058824 -0.5914 -0.4965 -0.4965 -0.7174  -0.8400 -1.2749
#
#        Eone    Etwo  ...    Btwo  Bthree   Bfour      surR     fiveR  \
# ...

# %%
lb=acorr_ljungbox(df['sur'], lags=10) #Ljung-Box test will be conducted to test for autocorrelation 
print (lb[1])
lb=acorr_ljungbox(df['five'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Efive'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Ethirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Esixty'], lags=10)
print (lb[1])
# Out:
# [0.22324554 0.15845536 0.29517675 0.39117163 0.3813517  0.44094868
#  0.46333776 0.55262767 0.53655366 0.38679751]
# [0.02795369 0.08462711 0.0168823  0.03443477 0.03692375 0.06323283
#  0.0557158  0.03015613 0.04874279 0.07418267]
# [2.92137951e-02 3.02474164e-02 1.48641558e-02 9.03125561e-03
#  4.60840808e-03 8.80533399e-03 7.88257205e-04 8.68486380e-05
#  1.53409914e-04 2.03478572e-04]
# [7.51996139e-02 9.16979256e-02 3.16814532e-03 2.52516489e-03
#  7.13297773e-04 1.61913952e-03 5.01112596e-05 8.66573257e-07
#  2.04435668e-06 3.23624615e-06]
# [0.12111387 0.22616087 0.37789335 0.35689675 0.13437618 0.16008626
#  0.01433794 0.01326938 0.02099744 0.0142671 ]
# [0.26350143 0.03691087 0.04233213 0.03342955 0.0442484  0.05591693
#  0.01157966 0.02050357 0.02978153 0.01774046]
# [0.99542088 0.02013188 0.03839718 0.07755826 0.07058121 0.10724303
#  0.04871968 0.07316201 0.1046978  0.03407599]

# %%
#Add a random signal
lb=acorr_ljungbox(df['surR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['fiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EfiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EthirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EsixtyR'], lags=10)
print (lb[1])
# Out:
# [0.13302974 0.11936679 0.22987237 0.29379412 0.31160432 0.35076297
#  0.41486512 0.51922437 0.53241938 0.39834654]
# [0.20341116 0.29105651 0.36263162 0.50129806 0.62773351 0.69694516
#  0.78516212 0.73780965 0.81635205 0.72527133]
# [0.00399852 0.00433392 0.01028406 0.00276229 0.00500298 0.00947053
#  0.00590372 0.00088614 0.00170012 0.00175386]
# [2.32416730e-01 4.76149503e-01 2.27368885e-02 2.80524620e-03
#  2.13255224e-05 3.02584423e-05 7.49363783e-06 2.28046648e-06
#  2.89863866e-06 6.02408133e-06]
# [0.21551258 0.43063007 0.63717472 0.69741854 0.19565009 0.27595268
#  0.12418557 0.15440682 0.21561702 0.14950175]
# [0.38046734 0.02598224 0.03411096 0.03606132 0.02064855 0.03482775
#  0.00504097 0.00694158 0.00924622 0.00247802]
# [0.89977332 0.13858113 0.26401178 0.38069574 0.28768358 0.40072399
#  0.17243039 0.24038736 0.31595987 0.13510287]
# ...

# %%
df=df.drop(columns='Unnamed: 0')
df.corr(method='pearson')['sur']
# Out:
# sur    1.000000
# 5m     0.370227
# 30m    0.216851
# 60m    0.125800
# E5     0.196526
# E30    0.015989
# E60   -0.027373
# Name: sur, dtype: float64

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data.xlsx',sheet_name='ExistingHome')
df=pd.DataFrame(df)

# %%
lb=acorr_ljungbox(df['sur'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['five'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Efive'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Ethirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Esixty'], lags=10)
print (lb[1])
# Out:
# [0.02206824 0.04473023 0.08109475 0.14343998 0.22447383 0.31052071
#  0.39061555 0.31207148 0.10077961 0.13937139]
# [0.01239419 0.0417846  0.08732609 0.15176647 0.20811725 0.10284231
#  0.15501619 0.22183121 0.25790533 0.26203353]
# [0.71483716 0.53083011 0.19302861 0.28605603 0.41311424 0.54021699
#  0.39312598 0.44648589 0.43016693 0.43598178]
# [0.30571957 0.14405974 0.1880121  0.28229038 0.3836362  0.50622146
#  0.50596155 0.0820103  0.12256194 0.14514241]
# [0.14200006 0.32544765 0.4532938  0.5954353  0.68283574 0.63115303
#  0.47587266 0.39184087 0.1874584  0.23206211]
# [0.02441073 0.07327065 0.1523459  0.16630918 0.16453416 0.15402948
#  0.14273195 0.20292987 0.21300435 0.02273849]
# [0.68477603 0.79271647 0.24031006 0.25262738 0.1433275  0.17241764
#  0.23703829 0.21544517 0.24277231 0.19148653]

# %%
#add a random signal
lb=acorr_ljungbox(df['surR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['fiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EfiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EthirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EsixtyR'], lags=10)
print (lb[1])
# Out:
# [0.02355804 0.04035015 0.07488477 0.13056946 0.20960931 0.26172415
#  0.32517091 0.24527767 0.08165721 0.11785972]
# [0.25957848 0.45937389 0.08350759 0.11538524 0.1713195  0.11700698
#  0.10112994 0.15169464 0.16249369 0.12688685]
# [0.97500129 0.11119648 0.21027757 0.10367625 0.17169229 0.24789493
#  0.27138515 0.36408055 0.44788332 0.29677823]
# [0.02407287 0.07561667 0.14620497 0.22804252 0.22811038 0.28317477
#  0.38313194 0.29070331 0.36061229 0.43048109]
# [0.21446492 0.43369599 0.18889673 0.24596711 0.34990268 0.23018882
#  0.26934745 0.20590866 0.27143512 0.34500187]
# [0.01602218 0.04813944 0.08501826 0.14808472 0.20203646 0.29732704
#  0.02122166 0.00831226 0.01426638 0.00520326]
# [0.84088299 0.75920637 0.56333042 0.38489388 0.41343403 0.54074942
#  0.64695691 0.74460872 0.80503293 0.75836584]

# %%
df=df.drop(columns='Unnamed: 0')
df.corr(method='pearson')['sur']
# Out:
# sur    1.000000
# 5m     0.134516
# 30m    0.027234
# 60m    0.002749
# E5     0.258182
# E30    0.116234
# E60    0.116487
# Name: sur, dtype: float64

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data.xlsx',sheet_name='BuildingPermit')
df=pd.DataFrame(df)

# %%
df=df.drop(columns='Unnamed: 0')
df.corr(method='pearson')['sur']
# Out:
# sur    1.000000
# 5m     0.092015
# 30m    0.120857
# 60m    0.048030
# E5     0.095717
# E30    0.035322
# E60    0.052523
# Name: sur, dtype: float64

# %%
lb=acorr_ljungbox(df['sur'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['five'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Efive'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Ethirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Esixty'], lags=10)
print (lb[1])
# Out:
# [0.88793614 0.98075335 0.99699951 0.3658661  0.48460516 0.59894321
#  0.71022128 0.71990529 0.76235253 0.82996754]
# [0.38733592 0.13233927 0.11107854 0.09576817 0.14710651 0.22464623
#  0.29801679 0.32429051 0.33203776 0.4076196 ]
# [0.25907562 0.23817965 0.2753397  0.27817373 0.38242668 0.50749916
#  0.42643053 0.24965278 0.33017064 0.32967722]
# [0.50659692 0.68929929 0.49126894 0.6528384  0.7711878  0.77350394
#  0.72384573 0.78950192 0.78048307 0.80112649]
# [0.88995545 0.69653239 0.69163468 0.79698316 0.82768933 0.62560382
#  0.25609781 0.28258705 0.3185767  0.24497678]
# [0.23077941 0.47125359 0.57326434 0.73432254 0.75834408 0.85440692
#  0.83887853 0.89378614 0.89997214 0.74279134]
# [0.82244035 0.93047269 0.97660028 0.88531224 0.82724393 0.87635221
#  0.87260457 0.81077687 0.78836908 0.7599534 ]

# %%
lb=acorr_ljungbox(df['surR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['fiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EfiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EthirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EsixtyR'], lags=10)
print (lb[1])
# Out:
# [0.9166732  0.96778315 0.99327502 0.49905691 0.62362792 0.73509602
#  0.82438083 0.8042965  0.86047932 0.91060912]
# [0.67911767 0.80405653 0.89208134 0.95325806 0.74647013 0.80130427
#  0.84565137 0.82353058 0.59533435 0.67827541]
# [0.27874152 0.50551412 0.65504874 0.24255888 0.16152306 0.2294148
#  0.21737907 0.29146871 0.32891769 0.40789144]
# [0.04680739 0.10804348 0.19440886 0.31728081 0.10015797 0.02388947
#  0.00500475 0.00747416 0.01122597 0.01845944]
# [0.26424266 0.48367962 0.69276575 0.75896645 0.86632286 0.74050255
#  0.80574044 0.6829099  0.76553856 0.80898094]
# [0.44798718 0.63271385 0.65001406 0.67740316 0.58004139 0.6902739
#  0.79063868 0.77235509 0.83538946 0.77997197]
# [0.29575337 0.52439754 0.70912457 0.83413511 0.73997163 0.83987196
#  0.89967037 0.83456532 0.89450805 0.87308982]

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data.xlsx',sheet_name='NFP ')
df=pd.DataFrame(df)

lb=acorr_ljungbox(df['Efive'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Ethirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Esixty'], lags=10)
print (lb[1])
# Out:
# [0.12111387 0.22616087 0.37789335 0.35689675 0.13437618 0.16008626
#  0.01433794 0.01326938 0.02099744 0.0142671 ]
# [0.26350143 0.03691087 0.04233213 0.03342955 0.0442484  0.05591693
#  0.01157966 0.02050357 0.02978153 0.01774046]
# [0.99542088 0.02013188 0.03839718 0.07755826 0.07058121 0.10724303
#  0.04871968 0.07316201 0.1046978  0.03407599]

# %%
df=df.drop(columns='Unnamed: 0')
df.corr(method='pearson')['sur']
# Out:
# sur    1.000000
# 5m     0.515365
# 30m    0.493154
# 60m    0.462391
# E5     0.391721
# E30    0.304378
# E60    0.310688
# Name: sur, dtype: float64

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data.xlsx',sheet_name='ADP ')
df=pd.DataFrame(df)

lb=acorr_ljungbox(df['sur'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['five'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Efive'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Ethirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Esixty'], lags=10)
print (lb[1])
# Out:
# [0.8303338  0.89829323 0.96633361 0.99188729 0.16130463 0.19864272
#  0.17125884 0.17082437 0.17896225 0.22344451]
# [0.98235366 0.82818455 0.34746168 0.22179399 0.29955636 0.19525686
#  0.12546897 0.18228928 0.1709252  0.22928203]
# [0.8545859  0.60727346 0.78928017 0.89776239 0.84207025 0.72139494
#  0.55877701 0.63219791 0.28515619 0.32283196]
# [0.34499074 0.57841383 0.73350218 0.5363472  0.47352979 0.16317386
#  0.16933286 0.10396477 0.14832505 0.1525487 ]
# [0.17320688 0.05258994 0.09125118 0.07459455 0.03838653 0.0476872
#  0.07711036 0.1168766  0.11842434 0.13020509]
# [0.16164578 0.15074224 0.27022293 0.09664298 0.0300481  0.03548864
#  0.05049249 0.07413505 0.03049648 0.02900435]
# [0.39194587 0.4828829  0.63305957 0.24290565 0.10947299 0.0053105
#  0.00559408 0.01026565 0.00396438 0.00429026]

# %%
#Add a random signal
lb=acorr_ljungbox(df['surR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['fiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EfiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EthirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EsixtyR'], lags=10)
print (lb[1])
# Out:
# [0.83949665 0.92368693 0.98378065 0.99638094 0.14143578 0.1741384
#  0.13525546 0.14329661 0.11206622 0.1493619 ]
# [0.02391138 0.07687054 0.13121788 0.21097219 0.16552284 0.08279473
#  0.13051667 0.1895945  0.20472459 0.13045458]
# [0.690274   0.46172527 0.40731366 0.51822448 0.6527413  0.62548975
#  0.72422353 0.77708847 0.82743486 0.87525053]
# [0.15420895 0.32460582 0.52044676 0.51065599 0.61550046 0.66878901
#  0.73182347 0.80404804 0.81927773 0.87511481]
# [0.53169201 0.81690079 0.9243187  0.78331554 0.87184912 0.85104404
#  0.82879587 0.8069844  0.52449572 0.60157329]
# [0.21117285 0.26499353 0.19477547 0.14961485 0.01092276 0.01788871
#  0.01112768 0.01727792 0.00919725 0.01227867]
# [0.47480185 0.33311655 0.33839031 0.15032352 0.10019823 0.01840047
#  0.01161615 0.02005319 0.01974778 0.02362807]

# %%
df=df.drop(columns='Unnamed: 0')
df.corr(method='pearson')['sur']
# Out:
# sur    1.000000
# 5m     0.561458
# 30m    0.294568
# 60m    0.264488
# E5     0.108908
# E30    0.117486
# E60    0.097268
# Name: sur, dtype: float64

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data.xlsx',sheet_name='IP ')
df=pd.DataFrame(df)

lb=acorr_ljungbox(df['sur'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['five'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Efive'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Ethirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Esixty'], lags=10)
print (lb[1])
# Out:
# [0.03698606 0.06779434 0.10871615 0.13211897 0.14890717 0.22324253
#  0.31392645 0.36242506 0.42517885 0.48026617]
# [0.4018916  0.37055104 0.47815746 0.50062113 0.6412976  0.12462198
#  0.16141442 0.22803353 0.30595183 0.37323729]
# [0.20506635 0.20011981 0.3267574  0.14123522 0.22712169 0.23375919
#  0.25144393 0.15024771 0.02515772 0.01746335]
# [0.87429942 0.7895469  0.27998904 0.24597138 0.35407808 0.46968916
#  0.54420375 0.65140278 0.74117748 0.3350983 ]
# [0.32741681 0.61618176 0.17375783 0.08757672 0.14992578 0.223266
#  0.11327996 0.13785848 0.19630305 0.01415698]
# [0.20506635 0.20011981 0.3267574  0.14123522 0.22712169 0.23375919
#  0.25144393 0.15024771 0.02515772 0.01746335]
# [0.15976987 0.10511915 0.21006751 0.33382165 0.41442732 0.4615496
#  0.47411988 0.48786669 0.49736911 0.38414317]

# %%
#add random signal
lb=acorr_ljungbox(df['surR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['fiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EfiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EthirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EsixtyR'], lags=10)
print (lb[1])
# Out:
# [0.12927395 0.21468835 0.3783815  0.45547023 0.34853599 0.47049212
#  0.584725   0.65926027 0.71694466 0.75432367]
# [0.73943143 0.94527816 0.93379905 0.8004183  0.8858863  0.93985545
#  0.95045197 0.97026151 0.68300239 0.41672054]
# [0.79084751 0.95048693 0.2158812  0.20556751 0.13470316 0.15781604
#  0.16539376 0.14704649 0.07042259 0.10348071]
# [0.30536934 0.27817452 0.34477499 0.38570329 0.37980968 0.41146432
#  0.4156876  0.44995586 0.50472856 0.33940338]
# [0.02528131 0.05746444 0.09186419 0.16255183 0.25118183 0.32823156
#  0.36327505 0.46673937 0.54815435 0.06309493]
# [0.12472944 0.20294566 0.31775784 0.31374067 0.40500037 0.50660899
#  0.41123442 0.48893483 0.31185299 0.35582042]
# [0.27630312 0.12740988 0.2032677  0.33042077 0.46248364 0.55536784
#  0.65833751 0.57645575 0.67051082 0.70361573]

# %%
df=df.drop(columns='Unnamed: 0')
df.corr(method='pearson')['sur']
# Out:
# sur    1.000000
# 5m     0.209330
# 30m    0.139032
# 60m    0.042632
# E5     0.021287
# E30    0.139032
# E60    0.025181
# Name: sur, dtype: float64

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data.xlsx',sheet_name='Capacity')
df=pd.DataFrame(df)

lb=acorr_ljungbox(df['sur'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['five'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Efive'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Ethirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Esixty'], lags=10)
print (lb[1])
# Out:
# [0.28075553 0.50798984 0.36954068 0.33732964 0.43942533 0.52388398
#  0.63477806 0.72789472 0.74628579 0.71651213]
# [0.4018916  0.37055104 0.47815746 0.50062113 0.6412976  0.12462198
#  0.16141442 0.22803353 0.30595183 0.37323729]
# [0.20506635 0.20011981 0.3267574  0.14123522 0.22712169 0.23375919
#  0.25144393 0.15024771 0.02515772 0.01746335]
# [0.87429942 0.7895469  0.27998904 0.24597138 0.35407808 0.46968916
#  0.54420375 0.65140278 0.74117748 0.3350983 ]
# [0.32741681 0.61618176 0.17375783 0.08757672 0.14992578 0.223266
#  0.11327996 0.13785848 0.19630305 0.01415698]
# [0.17110415 0.36525298 0.54378716 0.5531965  0.62655571 0.74491615
#  0.83032827 0.89302949 0.70146707 0.18725076]
# [0.15976987 0.10511915 0.21006751 0.33382165 0.41442732 0.4615496
#  0.47411988 0.48786669 0.49736911 0.38414317]

# %%
#add random signal
lb=acorr_ljungbox(df['surR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['fiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EfiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EthirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EsixtyR'], lags=10)
print (lb[1])
# Out:
# [0.33640841 0.57374807 0.41076135 0.41001027 0.52621501 0.62645421
#  0.7334613  0.80661848 0.84813753 0.7948326 ]
# [0.11536461 0.10527694 0.0904924  0.14801017 0.17816483 0.11965932
#  0.08086117 0.08216011 0.12274356 0.16475937]
# [0.29024014 0.51744959 0.67175306 0.53985992 0.51659355 0.59711531
#  0.54931797 0.56391102 0.66304201 0.56494006]
# [0.95549703 0.79226009 0.06651143 0.11216761 0.06550722 0.07541575
#  0.11480741 0.15279835 0.19499578 0.17480437]
# [0.69383201 0.75050904 0.29180599 0.11192792 0.16045171 0.24326241
#  0.11128193 0.13981644 0.19776107 0.06727178]
# [0.83919414 0.95477971 0.50722784 0.41120178 0.38622818 0.35945429
#  0.43368018 0.45688473 0.41884255 0.14217231]
# [0.70924949 0.37024499 0.57434911 0.73744804 0.85037309 0.91786892
#  0.89517803 0.73296533 0.72871445 0.52525842]

# %%
df=df.drop(columns='Unnamed: 0')
df.corr(method='pearson')['sur']
# Out:
# sur    1.000000
# 5m     0.196691
# 30m    0.087232
# 60m   -0.014710
# E5     0.130269
# E30    0.081669
# E60    0.125214
# Name: sur, dtype: float64

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data.xlsx',sheet_name='Consumer')
df=pd.DataFrame(df)

lb=acorr_ljungbox(df['sur'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['five'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Efive'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Ethirty'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Esixty'], lags=10)
print (lb[1])
# Out:
# [0.06957054 0.12644667 0.0359354  0.06739221 0.1146381  0.15425241
#  0.20167089 0.26903504 0.33127358 0.31807113]
# [0.61847853 0.81997548 0.93159844 0.88087426 0.93066469 0.93178122
#  0.89792967 0.90415061 0.66557997 0.47762191]
# [0.90395093 0.5137407  0.35176191 0.25066594 0.210989   0.22779368
#  0.31674418 0.30393127 0.38944119 0.48205042]
# [0.8433343  0.77416422 0.86768278 0.86634798 0.92469199 0.96540815
#  0.8979326  0.92544252 0.95821504 0.90537114]
# [0.79625482 0.44015092 0.38794803 0.51919493 0.46233464 0.59171409
#  0.43656408 0.14410542 0.20428089 0.2531623 ]
# [0.67129565 0.79601962 0.77035846 0.31702186 0.30815272 0.07401869
#  0.0774513  0.07813871 0.03869507 0.04275504]
# [0.03770572 0.1116296  0.22049065 0.06351261 0.05358538 0.0855574
#  0.13068054 0.18747345 0.25765322 0.33437484]

# %%
#add random signal
lb=acorr_ljungbox(df['surR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['fiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['thirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['sixtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EfiveR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EthirtyR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['EsixtyR'], lags=10)
print (lb[1])
# Out:
# [0.07986876 0.13666138 0.07730903 0.14192421 0.22731934 0.29445839
#  0.37452212 0.45793829 0.54751874 0.57445178]
# [2.03262616e-01 7.75504093e-04 1.59096470e-03 1.04087706e-04
#  1.13404723e-04 2.52475318e-05 3.87243789e-05 1.95237497e-05
#  4.17448931e-05 8.79608440e-05]
# [0.66059099 0.89601058 0.38808754 0.50910097 0.58385136 0.70781713
#  0.67656894 0.71060039 0.5999621  0.67161627]
# [0.41030382 0.70030366 0.39085499 0.53038168 0.00582587 0.0044424
#  0.00853782 0.01396317 0.01916183 0.01139671]
# [0.22413705 0.43148023 0.52584574 0.65373118 0.78002354 0.63612594
#  0.72321169 0.73455216 0.76995082 0.83904077]
# [0.40588873 0.66051392 0.70060537 0.46253347 0.06579964 0.04359758
#  0.05405062 0.08137868 0.11343388 0.10868426]
# [0.50992035 0.57714481 0.7590309  0.37610354 0.41440424 0.54175235
#  0.41155116 0.51586809 0.61531175 0.70421689]

# %%
df=df.drop(columns='Unnamed: 0')
df.corr(method='pearson')['sur']
# Out:
# sur         1.000000
# five       -0.124150
# thirty      0.155484
# sixty      -0.051932
# Efive       0.078437
# Ethirty    -0.127317
# Esixty      0.024836
# surR        0.994799
# fiveR      -0.046701
# thirtyR     0.039100
# sixtyR     -0.053950
# EfiveR      0.020703
# EthirtyR   -0.129716
# EsixtyR     0.019185
# Name: sur, dtype: float64

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data1.xlsx',sheet_name='NFP ')
df=pd.DataFrame(df)

lb=acorr_ljungbox(df['Bone'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Btwo'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Bthree'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Bfour'], lags=10)
print (lb[1])
# Out:
# [0.3822085  0.58102165 0.3783351  0.47975279 0.57101533 0.67250749
#  0.77454931 0.70658205 0.79136842 0.81153491]
# [0.73941243 0.80524063 0.92783174 0.97702007 0.80304383 0.87675264
#  0.93186471 0.79731775 0.865385   0.91455048]
# [0.64186215 0.81874408 0.93946909 0.84660021 0.7840168  0.80606468
#  0.88080767 0.79930925 0.85636715 0.90702696]
# [0.60252778 0.85759403 0.92171049 0.70923652 0.73152661 0.75462657
#  0.80054445 0.74759517 0.82611992 0.88236904]

# %%
#add random signal
lb=acorr_ljungbox(df['BoneR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['BtwoR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['BthreeR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['BfourR'], lags=10)
print (lb[1])
# Out:
# [0.50106916 0.61771551 0.3465397  0.39260466 0.50388462 0.56980756
#  0.6719035  0.60176155 0.69844075 0.71520769]
# [0.85209232 0.91695324 0.98128679 0.99001995 0.85915993 0.91902958
#  0.95943141 0.89301514 0.92961601 0.95774635]
# [0.57694371 0.53587592 0.71639015 0.69065174 0.60615872 0.69630194
#  0.77646079 0.74253651 0.81443317 0.87577769]
# [0.460864   0.71351257 0.84546876 0.66988027 0.77095278 0.80002359
#  0.85984201 0.7955202  0.86428498 0.91313144]

# %%
df = pd.read_excel (r'C:\Users\SS\Downloads\data1.xlsx',sheet_name='ADP ')
df=pd.DataFrame(df)

lb=acorr_ljungbox(df['Bone'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Btwo'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Bthree'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['Bfour'], lags=10)
print (lb[1])
# Out:
# [0.22324824 0.01201536 0.02909849 0.01850167 0.03603965 0.05502324
#  0.05191241 0.07748982 0.06953175 0.09219073]
# [0.63958889 0.00101727 0.00188643 0.00103443 0.00239757 0.00427572
#  0.00514824 0.00657253 0.01087236 0.01662447]
# [0.87181606 0.00185936 0.00513961 0.00519443 0.01117869 0.01860624
#  0.03291243 0.04075816 0.05663926 0.08365847]
# [0.41073269 0.04486995 0.10185071 0.16089966 0.24542767 0.3282303
#  0.42764491 0.47972475 0.54921503 0.5708706 ]

# %%
#add random signal
lb=acorr_ljungbox(df['BoneR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['BtwoR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['BthreeR'], lags=10)
print (lb[1])
lb=acorr_ljungbox(df['BfourR'], lags=10)
print (lb[1])
# Out:
# [0.47653687 0.28574768 0.35452348 0.49895531 0.54905971 0.43804679
#  0.4203715  0.31584136 0.35569628 0.43745159]
# [0.7617881  0.00734257 0.01660394 0.00971088 0.02033641 0.03651483
#  0.0574793  0.07239749 0.08789978 0.11986294]
# [0.49995282 0.06566458 0.11535709 0.15039663 0.2215732  0.31805615
#  0.42118276 0.30186293 0.39237544 0.34786128]
# [0.10916385 0.23152357 0.2764733  0.41486396 0.53818487 0.66594001
#  0.76422436 0.81071639 0.87564739 0.92100667]

# %%
x=np.array(train_data['sur']).reshape(-1,1)
y=np.array(train_data['Bone']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 10Y Treasury Bond Yield (1min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.40731377]]
# intercept: [0.26168757]

# %%
#regression results after adding a random signal 
x=np.array(train_data['surR']).reshape(-1,1)
y=np.array(train_data['BoneR']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 10Y Treasury Bond Yield (1min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.31634939]]
# intercept: [0.41738975]

# %%
x=np.array(train_data['sur']).reshape(-1,1)
y=np.array(train_data['Btwo']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 10Y Treasury Bond Yield (2min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.41479034]]
# intercept: [0.38653225]

# %%
x=np.array(train_data['surR']).reshape(-1,1)
y=np.array(train_data['BtwoR']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 10Y Treasury Bond Yield (2min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.3762367]]
# intercept: [0.46604892]

# %%
x=np.array(train_data['sur']).reshape(-1,1)
y=np.array(train_data['Bthree']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 10Y Treasury Bond Yield (3min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.42539176]]
# intercept: [0.34783656]

# %%
#Add random signal
x=np.array(train_data['surR']).reshape(-1,1)
y=np.array(train_data['BfourR']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 10Y Treasury Bond Yield (3min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.38921197]]
# intercept: [0.5129859]

# %%
x=np.array(train_data['sur']).reshape(-1,1)
y=np.array(train_data['Bfour']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 10Y Treasury Bond Yield (4min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.443816]]
# intercept: [0.36516743]

# %%
x=np.array(train_data['surR']).reshape(-1,1)
y=np.array(train_data['BfourR']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 10Y Treasury Bond Yield (4min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.38921197]]
# intercept: [0.5129859]

# %%
import seaborn as sns
#Plot pairwise correlation between macroeconomic releases
sns.set(style='whitegrid',context='notebook')
df=pd.read_excel(r'C:\Users\SS\Downloads\data.xlsx',sheet_name='pairwise')
cols=['NFP','BuildingPermit','NewHome','ExistingHome','ADP','IP','CapacityUtilization','ConsumerCredit']
sns.pairplot(df[cols],size=2.5)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SS\anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#plot a correlation heat map
cm=np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)
hm=sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size':15},yticklabels=cols,xticklabels=cols)
plt.show()

# %%
train_data=pd.read_excel(r'C:\Users\SS\Downloads\data-Bond.xlsx',sheet_name='NFP ')
x=np.array(train_data['sur']).reshape(-1,1)
y=np.array(train_data['One']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 30Y Treasury Bond Yield (1min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.17815781]]
# intercept: [0.12810421]

# %%
#add random signal
x=np.array(train_data['surR']).reshape(-1,1)
y=np.array(train_data['OneR']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 30Y Treasury Bond Yield (1min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.15285602]]
# intercept: [0.09150205]

# %%
x=np.array(train_data['sur']).reshape(-1,1)
y=np.array(train_data['Two']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 30Y Treasury Bond Yield (2min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.19640014]]
# intercept: [0.21959877]

# %%
#add random signal
x=np.array(train_data['surR']).reshape(-1,1)
y=np.array(train_data['TwoR']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 30Y Treasury Bond Yield (2min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.23717391]]
# intercept: [0.22735177]

# %%
x=np.array(train_data['sur']).reshape(-1,1)
y=np.array(train_data['Three']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 30Y Treasury Bond Yield (3min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.20801706]]
# intercept: [0.22192272]

# %%
#add random signal
x=np.array(train_data['surR']).reshape(-1,1)
y=np.array(train_data['ThreeR']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 30Y Treasury Bond Yield (3min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.18915945]]
# intercept: [0.28279719]

# %%
x=np.array(train_data['sur']).reshape(-1,1)
y=np.array(train_data['Four']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 30Y Treasury Bond Yield (4min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.21083968]]
# intercept: [0.23550998]

# %%
#add random signal
x=np.array(train_data['surR']).reshape(-1,1)
y=np.array(train_data['FourR']).reshape(-1,1)
regr=linear_model.LinearRegression()
regr.fit(x,y)
a=regr.coef_
b=regr.intercept_
Y=a*x+b
plt.scatter(x,y)
plt.plot(x,Y)
plt.title('NFP and US 30Y Treasury Bond Yield (4min)')
plt.show()
print('coefficient:', regr.coef_)
print('intercept:',regr.intercept_)
# Out:
# coefficient: [[0.20112067]]
# intercept: [0.33738288]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model
import matplotlib.pyplot as plt
#LogisticRegression on NFP surprises and one-minute US 10Y treasury bond yield changes
train_data=pd.read_excel(r'C:\Users\SS\Downloads\data.xlsx',sheet_name='NFP')
train_x=train_data['sur']
train_y=train_data['One']
train_x=np.array(train_x).reshape(-1,1)
train_y=np.array(train_y).reshape(-1,1)

# %%
model=LogisticRegression(solver='liblinear')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(train_x,train_y,test_size=0.1,random_state=0)
model.fit(X_train,y_train)
# Out:
# C:\Users\SS\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.predict(X_test)
model.score(X_test,y_test)
# Out:
# 0.8

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[3 0]
#  [2 5]]

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot
from sklearn.metrics import roc_auc_score
ns_probs = [0 for _ in range(len(y_test))]
# fit a model
# predict probabilities
lr_probs = model.predict_proba(X_test)
# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]
# calculate scores
ns_auc = roc_auc_score(y_test, ns_probs)
lr_auc = roc_auc_score(y_test, lr_probs)
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Logistic: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
# plot the roc curve for the model
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
pyplot.plot(lr_fpr, lr_tpr, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.857
# Text(0, 0.5, 'True Positive Rate')

# %%
train_y=train_data['Two']
model.fit(X_train,y_train)
model.predict(X_test)
model.score(X_test,y_test)
# Out:
# C:\Users\SS\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8

# %%
from sklearn.metrics import plot_confusion_matrix
#plot confusion matrix which shows number of correct and incorrect predictions
plot_confusion_matrix(model, X_test, y_test) 
plt.show()

# %%
ns_probs = [0 for _ in range(len(y_test))]
# fit a model
# predict probabilities
lr_probs = model.predict_proba(X_test)
# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]
# calculate scores
ns_auc = roc_auc_score(y_test, ns_probs)
lr_auc = roc_auc_score(y_test, lr_probs)
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Logistic: ROC AUC=%.3f' % (lr_auc))
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
# plot the roc curve for the model
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
pyplot.plot(lr_fpr, lr_tpr, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
pyplot.show()
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.857

# %%
train_y=train_data['Three']
model.fit(X_train,y_train)
model.predict(X_test)
model.score(X_test,y_test)
# Out:
# C:\Users\SS\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8

# %%
train_y=train_data['Four']
model.fit(X_train,y_train)
model.predict(X_test)
model.score(X_test,y_test)
# Out:
# C:\Users\SS\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8
